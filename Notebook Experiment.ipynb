# %% [markdown]
# # Notebook Experiment #

# %% [markdown]
# *By Jafed Encinas*

# %% [markdown]
# A suitable location for house purchase would be at the centre of biggest businesses so as to maximise the house price potential. A clustering algorithm would be performed on the locations of houses and businesses separately to find the concentration of both types of the establishments.

# %%
# Nessecary Imports
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# Make the figure
plt.figure(figsize=(14, 14))
# Initialize the basemap
m = Basemap(llcrnrlat = 30,
            llcrnrlon = -126,
            urcrnrlat = 45,
            urcrnrlon = -114,
           resolution='h')
# Get the area of interest imagery
m.arcgisimage(service='ESRI_Imagery_World_2D', xpixels = 2500, verbose= True,alpha= .6)
# Draw the coasts
m.drawcoastlines(color='blu', linewidth=3)
# Draw the states
m.drawstates(color='red',linewidth=3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-577a172b1b58> in <module>()
#       1 # Nessecary Imports
#       2 import matplotlib.pyplot as plt
# ----> 3 from mpl_toolkits.basemap import Basemap
#       4 # Make the figure
#       5 plt.figure(figsize=(14, 14))
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %% [markdown]
# ## 1.0 Find people density ##

# %%
import pandas as pd
import numpy as np
# Read in data on all cities
cities = pd.read_csv('uscitiesv1.4.csv')
# Choose only cities in california
cities = cities.loc[cities.state_id == 'CA',:]
# Get all the data from the dataframe
lat, lon = cities['lat'], cities['lng']
population,density = cities['population'], cities['density']
# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population),s= 10*np.log(density),
            cmap='viridis', linewidth=0, alpha= .4)
plt.axis(aspect='equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)
# make a guide for the user
for density in [1, 50//3, 50]:
    plt.scatter([], [], c='k', alpha=0.3, s=5*np.log(density),
                label='10* log('+str(density) + ')')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Density')
# add a title
plt.title('California Cities: Density and Population');
# Out:
# /Users/jafedencinas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':

# %% [markdown]
# ## 2.0 Find postal codes valuations ##

# %%
import csv

with open('california.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} has the value of {row[1]} points.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are Postal Code, Value
# 	85000 has the value of 100 points.
# 	85001 has the value of 101 points.
# 	85002 has the value of 102 points.
# 	85003 has the value of 103 points.
# 	85004 has the value of 104 points.
# 	85005 has the value of 105 points.
# 	85006 has the value of 106 points.
# 	85007 has the value of 107 points.
# 	85008 has the value of 108 points.
# 	85009 has the value of 109 points.
# 	85010 has the value of 110 points.
# 	85011 has the value of 111 points.
# 	85012 has the value of 112 points.
# 	85013 has the value of 113 points.
# 	85014 has the value of 114 points.
# 	85015 has the value of 115 points.
# 	85016 has the value of 116 points.
# 	85017 has the value of 117 points.
# 	85018 has the value of 118 points.
# 	85019 has the value of 119 points.
# 	85020 has the value of 120 points.
# 	85021 has the value of 121 points.
# 	85022 has the value of 122 points.
# 	85023 has the value of 123 points.
# 	85024 has the value of 124 points.
# ...

# %% [markdown]
# ### Top 10 values ##

# %% [markdown]
# - 90000 has the value of 5100 points.
# - 90001 has the value of 5101 points.
# - 90002 has the value of 5102 points.
# - 90003 has the value of 5103 points.
# - 90004 has the value of 5104 points.
# - 90005 has the value of 5105 points.
# - 90006 has the value of 5106 points.
# - 90007 has the value of 5107 points.
# - 90008 has the value of 5108 points.
# - 90009 has the value of 5109 points.
# - 90010 has the value of 5110 points.
